# %%
from Dutch import *

# %%
game = Dutch()
game.joue()
# Out:
# C'est au joueur : joueur1 de jouer
# La main: [coeur.3, pique.dame, carreau.5, carreau.dame]
# pioche ou prend:pioche
# Voici la carte : ♣ 8
